# %% [markdown]
# <a href="https://colab.research.google.com/github/GYAN2020/Authentication/blob/main/MinMaxScaler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Min Max Scaler**

# %% [markdown]
# In MinMaxScalar feature value lie between 0 and 1

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/auto-mpg.csv')

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          87       1              amc rebel sst
# 4          70       1                ford torino

# %%
df.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
X=df.iloc[:,[2,4]]
y=df.iloc[:,5]

# %%
print(X)
# Out:
#      displacement  weight
# 0           307.0    3504
# 1           350.0    3693
# 2           318.0    3436
# 3           304.0    3433
# 4           302.0    3449
# ..            ...     ...
# 393         140.0    2790
# 394          97.0    2130
# 395         135.0    2295
# 396         120.0    2625
# 397         119.0    2720
#
# [398 rows x 2 columns]

# %%
print(y)
# Out:
# 0      12.0
# 1      11.5
# 2      11.0
# 3      12.0
# 4      10.5
#        ...
# 393    15.6
# 394    24.6
# 395    11.6
# 396    18.6
# 397    19.4
# Name: acceleration, Length: 398, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=40)

# %%
X_train.head()
# Out:
#      displacement  weight
# 256         225.0    3430
# 295          98.0    1915
# 100         250.0    3021
# 253         200.0    3155
# 369         112.0    2395

# %%
scaler=MinMaxScaler().fit(X_train)

# %%
print(scaler)
# Out:
# MinMaxScaler()

# %%
scaler.data_max_
# Out:
# array([ 455., 5140.])

# %%
X_train.describe()
# Out:
#        displacement       weight
# count    298.000000   298.000000
# mean     193.293624  2978.661074
# std      102.611154   828.696625
# min       68.000000  1613.000000
# 25%      105.500000  2265.000000
# 50%      151.000000  2824.000000
# 75%      260.000000  3556.000000
# max      455.000000  5140.000000

# %%
scaler.feature_range
# Out:
# (0, 1)

# %%
scaler.transform(X_train)
# Out:
# array([[0.40568475, 0.5151687 ],
#        [0.07751938, 0.08562518],
#        [0.47028424, 0.39920612],
#        [0.34108527, 0.43719875],
#        [0.11369509, 0.22171817],
#        [0.13953488, 0.19761837],
#        [0.19638243, 0.29827048],
#        [0.00775194, 0.04536433],
#        [0.64599483, 0.71647292],
#        [0.09560724, 0.15225404],
#        [0.42377261, 0.47490785],
#        [0.51421189, 0.56478594],
#        [0.10077519, 0.23164162],
#        [0.64599483, 0.73064928],
#        [0.50129199, 0.39750496],
#        [0.12144703, 0.30649277],
#        [0.34108527, 0.38332861],
#        [0.93281654, 0.94669691],
#        [0.0749354 , 0.16302807],
#        [0.60465116, 0.44116813],
#        [0.6124031 , 0.64275588],
#        [0.42118863, 0.50099234],
#        [0.13953488, 0.17210094],
#        [0.01033592, 0.        ],
#        [0.02842377, 0.10972498],
#        [0.10077519, 0.24128154],
#        [0.72868217, 0.78451942],
#        [0.18604651, 0.36206408],
# ...

# %%
x_train_scaled=scaler.transform(X_train)

# %%
print(x_train_scaled)
# Out:
# [[0.40568475 0.5151687 ]
#  [0.07751938 0.08562518]
#  [0.47028424 0.39920612]
#  [0.34108527 0.43719875]
#  [0.11369509 0.22171817]
#  [0.13953488 0.19761837]
#  [0.19638243 0.29827048]
#  [0.00775194 0.04536433]
#  [0.64599483 0.71647292]
#  [0.09560724 0.15225404]
#  [0.42377261 0.47490785]
#  [0.51421189 0.56478594]
#  [0.10077519 0.23164162]
#  [0.64599483 0.73064928]
#  [0.50129199 0.39750496]
#  [0.12144703 0.30649277]
#  [0.34108527 0.38332861]
#  [0.93281654 0.94669691]
#  [0.0749354  0.16302807]
#  [0.60465116 0.44116813]
#  [0.6124031  0.64275588]
#  [0.42118863 0.50099234]
#  [0.13953488 0.17210094]
#  [0.01033592 0.        ]
#  [0.02842377 0.10972498]
#  [0.10077519 0.24128154]
#  [0.72868217 0.78451942]
#  [0.18604651 0.36206408]
#  [0.72868217 0.77884888]
#  [0.00516796 0.22880635]
#  [0.64599483 0.65976751]
#  [0.73126615 0.73773745]
#  [0.81395349 0.5528778 ]
#  [0.25839793 0.36773462]
#  [0.60981912 0.88432095]
#  [0.18863049 0.45846328]
#  [0.85788114 0.8083357 ]
# ...

# %%
scaler.data_min_
# Out:
# array([  68., 1613.])

# %%
scaler.data_max_
# Out:
# array([ 455., 5140.])

# %%
scaler.feature_range
# Out:
# (0, 1)

# %%
X_test.describe()
# Out:
#        displacement       weight
# count     100.00000   100.000000
# mean      219.92000  2945.880000
# std       300.79278   902.652089
# min        78.00000  1795.000000
# 25%        97.75000  2128.750000
# 50%       140.00000  2655.500000
# 75%       302.00000  3737.750000
# max      3000.00000  4955.000000

# %%
scaler.transform(X_test)
# Out:
# array([[0.02842377, 0.09923448],
#        [0.40568475, 0.56705415],
#        [0.1369509 , 0.25460731],
#        [0.02583979, 0.10547207],
#        [0.12403101, 0.15452226],
#        [0.42377261, 0.36886873],
#        [0.12403101, 0.17210094],
#        [0.05943152, 0.09696626],
#        [0.81395349, 0.94754749],
#        [0.05943152, 0.05160193],
#        [0.60981912, 0.51601928],
#        [0.22739018, 0.27558832],
#        [0.0749354 , 0.09554862],
#        [0.13436693, 0.15508931],
#        [0.85788114, 0.88829033],
#        [0.18604651, 0.29089878],
#        [0.60981912, 0.58378225],
#        [0.60465116, 0.52055571],
#        [0.61757106, 0.78338531],
#        [0.0749354 , 0.1465835 ],
#        [0.60465116, 0.85766941],
#        [0.18863049, 0.4471222 ],
#        [0.1627907 , 0.34505245],
#        [0.73126615, 0.71335413],
#        [0.0749354 , 0.15820811],
#        [0.05943152, 0.10547207],
#        [0.49095607, 0.60022682],
#        [7.57622739, 0.63425007],
# ...

# %%
X_test_scaled=scaler.transform(X_test)

# %%
print(X_test_scaled)
# Out:
# [[0.02842377 0.09923448]
#  [0.40568475 0.56705415]
#  [0.1369509  0.25460731]
#  [0.02583979 0.10547207]
#  [0.12403101 0.15452226]
#  [0.42377261 0.36886873]
#  [0.12403101 0.17210094]
#  [0.05943152 0.09696626]
#  [0.81395349 0.94754749]
#  [0.05943152 0.05160193]
#  [0.60981912 0.51601928]
#  [0.22739018 0.27558832]
#  [0.0749354  0.09554862]
#  [0.13436693 0.15508931]
#  [0.85788114 0.88829033]
#  [0.18604651 0.29089878]
#  [0.60981912 0.58378225]
#  [0.60465116 0.52055571]
#  [0.61757106 0.78338531]
#  [0.0749354  0.1465835 ]
#  [0.60465116 0.85766941]
#  [0.18863049 0.4471222 ]
#  [0.1627907  0.34505245]
#  [0.73126615 0.71335413]
#  [0.0749354  0.15820811]
#  [0.05943152 0.10547207]
#  [0.49095607 0.60022682]
#  [7.57622739 0.63425007]
#  [0.72868217 0.81825914]
#  [0.10335917 0.18485965]
#  [0.05426357 0.10065211]
#  [0.34108527 0.41309895]
#  [0.07751938 0.18202438]
#  [0.13178295 0.22455344]
#  [0.72868217 0.80153105]
#  [0.26614987 0.38871562]
#  [0.21447028 0.28976467]
# ...
